# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Vectorise Environment

# %%
from crowd_sim.envs.crowd_sim_sgan import CrowdSimSgan
from crowd_sim.envs.crowd_sim_sgan_apf import CrowdSimSganApf
from crowd_sim.envs.crowd_sim_no_pred import CrowdSimNoPred
import gym
import time
import numpy as np

# %%
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv, VecTransposeImage
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3 import PPO, A2C

# %%
from arguments import get_args
from crowd_nav.configs.config import Config

config = Config()

# %%
def make_env(seed, rank, env_config, envNum=1):
    """
    Utility function for multiprocessed env.

    :param env_id: (str) the environment ID
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    """

    def _init():
        env = CrowdSimSganApf()
        # use a seed for reproducibility
        # Important: use a different seed for each environment
        # otherwise they would generate the same experiences
        env.configure(env_config)
        env.seed(seed + rank)
        env.setup(seed=seed+rank, num_of_env=envNum)
        return env

    return _init

# %%
num_cpu = 1  # Number of processes to use
seed = 0

venv = SubprocVecEnv([make_env(seed, i, config, num_cpu) for i in range(num_cpu)])
venv = VecTransposeImage(venv)

# %%
# obs = venv.reset()
# obs.shape

# %% [markdown]
# ## Collecting dataset

# %%
from imitation_learning import rollout
rng = np.random.default_rng()

# %%
rollouts = rollout.rollout(
    policy=None,
    venv=venv,
    sample_until=rollout.make_sample_until(min_timesteps=None, min_episodes=60),
    rng=rng,
    unwrap=False,
    exclude_infos=True,
    verbose=True
)
# Out:
# Rollout stats: {'n_traj': 60, 'return_min': -12.255129237337709, 'return_mean': 29.088985581059507, 'return_std': 11.06672175559258, 'return_max': 48.69290168355165, 'len_min': 22, 'len_mean': 49.916666666666664, 'len_std': 17.61655629104495, 'len_max': 95}

# %% [markdown]
# ## Save and load dataset

# %%
from imitation.data import serialize
dataset_path = './train/dataset/8ppl_240mapsize_100eps'

# %%
# save dataset
serialize.save(dataset_path, rollouts)

# %%
# load dataset
rollouts = serialize.load(dataset_path)

# %% [markdown]
# # GAIL

# %%
from stable_baselines3 import PPO
from imitation.algorithms.adversarial.gail import GAIL
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm

# %%
learner = PPO(
    env=venv,
    policy='CnnPolicy',
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0003,
    n_epochs=10,
)

# %%
reward_net = BasicRewardNet(
    venv.observation_space, venv.action_space, normalize_input_layer=RunningNorm
)

# %%
gail_trainer = GAIL(
    demonstrations=rollouts,
    demo_batch_size=64,
    gen_replay_buffer_capacity=1024,
    n_disc_updates_per_round=4,
    venv=venv,
    gen_algo=learner,
    reward_net=reward_net,
    allow_variable_horizon=True
)
# Out:
# Running with `allow_variable_horizon` set to True. Some algorithms are biased towards shorter or longer episodes, which may significantly confound results. Additionally, even unbiased algorithms can exploit the information leak from the termination condition, producing spuriously high performance. See https://imitation.readthedocs.io/en/latest/getting-started/variable-horizon.html for more information.

# %%
gail_trainer.train(300000)
# Out:
# round:   0%|                                            | 0/146 [00:00<?, ?it/s]
# --------------------------------------
# | raw/                        |      |
# |    gen/time/fps             | 37   |
# |    gen/time/iterations      | 1    |
# |    gen/time/time_elapsed    | 54   |
# |    gen/time/total_timesteps | 2048 |
# --------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.57     |
# |    disc/disc_acc_expert             | 0.203    |
# |    disc/disc_acc_gen                | 0.938    |
# |    disc/disc_entropy                | 0.693    |
# |    disc/disc_loss                   | 0.688    |
# |    disc/disc_proportion_expert_pred | 0.133    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.609    |
# |    disc/disc_acc_expert             | 0.812    |
# |    disc/disc_acc_gen                | 0.406    |
# |    disc/disc_entropy                | 0.218    |
# |    disc/disc_loss                   | 1.27     |
# |    disc/disc_proportion_expert_pred | 0.703    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.836    |
# |    disc/disc_acc_expert             | 0.703    |
# |    disc/disc_acc_gen                | 0.969    |
# |    disc/disc_entropy                | 0.18     |
# |    disc/disc_loss                   | 0.716    |
# |    disc/disc_proportion_expert_pred | 0.367    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.695    |
# |    disc/disc_acc_expert             | 0.703    |
# |    disc/disc_acc_gen                | 0.688    |
# |    disc/disc_entropy                | 0.193    |
# |    disc/disc_loss                   | 1.13     |
# |    disc/disc_proportion_expert_pred | 0.508    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# ---------------------------------------------------
# | mean/                               |           |
# |    disc/disc_acc                    | 0.678     |
# |    disc/disc_acc_expert             | 0.605     |
# |    disc/disc_acc_gen                | 0.75      |
# |    disc/disc_entropy                | 0.321     |
# |    disc/disc_loss                   | 0.952     |
# |    disc/disc_proportion_expert_pred | 0.428     |
# |    disc/disc_proportion_expert_true | 0.5       |
# |    disc/global_step                 | 1         |
# |    disc/n_expert                    | 64        |
# |    disc/n_generated                 | 64        |
# |    gen/time/fps                     | 37        |
# |    gen/time/iterations              | 1         |
# |    gen/time/time_elapsed            | 54        |
# |    gen/time/total_timesteps         | 2.05e+03  |
# |    gen/train/approx_kl              | 0.00752   |
# |    gen/train/clip_fraction          | 0.165     |
# |    gen/train/clip_range             | 0.2       |
# |    gen/train/entropy_loss           | -2.82     |
# |    gen/train/explained_variance     | -0.000352 |
# |    gen/train/learning_rate          | 0.0003    |
# |    gen/train/loss                   | 1.46      |
# |    gen/train/n_updates              | 10        |
# |    gen/train/policy_gradient_loss   | 0.000405  |
# |    gen/train/std                    | 0.988     |
# |    gen/train/value_loss             | 6.83      |
# ---------------------------------------------------
# round:   1%|▏                                 | 1/146 [01:05<2:39:04, 65.82s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_rew_wrapped_mean | 80.4         |
# |    gen/time/fps                    | 40           |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 50           |
# |    gen/time/total_timesteps        | 4096         |
# |    gen/train/approx_kl             | 0.0075228335 |
# |    gen/train/clip_fraction         | 0.165        |
# |    gen/train/clip_range            | 0.2          |
# |    gen/train/entropy_loss          | -2.82        |
# |    gen/train/explained_variance    | -0.000352    |
# |    gen/train/learning_rate         | 0.0003       |
# |    gen/train/loss                  | 1.46         |
# |    gen/train/n_updates             | 10           |
# |    gen/train/policy_gradient_loss  | 0.000405     |
# |    gen/train/std                   | 0.988        |
# |    gen/train/value_loss            | 6.83         |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.695    |
# |    disc/disc_acc_expert             | 0.641    |
# |    disc/disc_acc_gen                | 0.75     |
# |    disc/disc_entropy                | 0.184    |
# |    disc/disc_loss                   | 1.06     |
# |    disc/disc_proportion_expert_pred | 0.445    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.797    |
# |    disc/disc_acc_expert             | 0.766    |
# |    disc/disc_acc_gen                | 0.828    |
# |    disc/disc_entropy                | 0.187    |
# |    disc/disc_loss                   | 0.749    |
# |    disc/disc_proportion_expert_pred | 0.469    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.781    |
# |    disc/disc_acc_expert             | 0.688    |
# |    disc/disc_acc_gen                | 0.875    |
# |    disc/disc_entropy                | 0.19     |
# |    disc/disc_loss                   | 0.633    |
# |    disc/disc_proportion_expert_pred | 0.406    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.883    |
# |    disc/disc_acc_expert             | 0.844    |
# |    disc/disc_acc_gen                | 0.922    |
# |    disc/disc_entropy                | 0.156    |
# |    disc/disc_loss                   | 0.425    |
# |    disc/disc_proportion_expert_pred | 0.461    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.789    |
# |    disc/disc_acc_expert             | 0.734    |
# |    disc/disc_acc_gen                | 0.844    |
# |    disc/disc_entropy                | 0.179    |
# |    disc/disc_loss                   | 0.717    |
# |    disc/disc_proportion_expert_pred | 0.445    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 80.4     |
# |    gen/time/fps                     | 40       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 50       |
# |    gen/time/total_timesteps         | 4.1e+03  |
# |    gen/train/approx_kl              | 0.016    |
# |    gen/train/clip_fraction          | 0.206    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -2.81    |
# |    gen/train/explained_variance     | -0.0265  |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 28.3     |
# |    gen/train/n_updates              | 20       |
# |    gen/train/policy_gradient_loss   | 0.0145   |
# |    gen/train/std                    | 0.986    |
# |    gen/train/value_loss             | 223      |
# --------------------------------------------------
# round:   1%|▍                                 | 2/146 [02:07<2:32:42, 63.63s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_rew_wrapped_mean | 127         |
# |    gen/time/fps                    | 45          |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 45          |
# |    gen/time/total_timesteps        | 6144        |
# |    gen/train/approx_kl             | 0.015974281 |
# |    gen/train/clip_fraction         | 0.206       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -2.81       |
# |    gen/train/explained_variance    | -0.0265     |
# |    gen/train/learning_rate         | 0.0003      |
# |    gen/train/loss                  | 28.3        |
# |    gen/train/n_updates             | 20          |
# |    gen/train/policy_gradient_loss  | 0.0145      |
# |    gen/train/std                   | 0.986       |
# |    gen/train/value_loss            | 223         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.523    |
# |    disc/disc_acc_expert             | 0.812    |
# |    disc/disc_acc_gen                | 0.234    |
# |    disc/disc_entropy                | 0.186    |
# |    disc/disc_loss                   | 1.81     |
# |    disc/disc_proportion_expert_pred | 0.789    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.797    |
# |    disc/disc_acc_expert             | 0.828    |
# |    disc/disc_acc_gen                | 0.766    |
# |    disc/disc_entropy                | 0.193    |
# |    disc/disc_loss                   | 0.457    |
# |    disc/disc_proportion_expert_pred | 0.531    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.867    |
# |    disc/disc_acc_expert             | 0.734    |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.152    |
# |    disc/disc_loss                   | 0.566    |
# |    disc/disc_proportion_expert_pred | 0.367    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.758    |
# |    disc/disc_acc_expert             | 0.625    |
# |    disc/disc_acc_gen                | 0.891    |
# |    disc/disc_entropy                | 0.123    |
# |    disc/disc_loss                   | 1.07     |
# |    disc/disc_proportion_expert_pred | 0.367    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.736    |
# |    disc/disc_acc_expert             | 0.75     |
# |    disc/disc_acc_gen                | 0.723    |
# |    disc/disc_entropy                | 0.164    |
# |    disc/disc_loss                   | 0.975    |
# |    disc/disc_proportion_expert_pred | 0.514    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 127      |
# |    gen/time/fps                     | 45       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 45       |
# |    gen/time/total_timesteps         | 6.14e+03 |
# |    gen/train/approx_kl              | 0.0138   |
# |    gen/train/clip_fraction          | 0.241    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -2.81    |
# |    gen/train/explained_variance     | 0.123    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 100      |
# |    gen/train/n_updates              | 30       |
# |    gen/train/policy_gradient_loss   | 0.0235   |
# |    gen/train/std                    | 0.986    |
# |    gen/train/value_loss             | 289      |
# --------------------------------------------------
# round:   2%|▋                                 | 3/146 [03:04<2:24:04, 60.45s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_rew_wrapped_mean | 159         |
# |    gen/time/fps                    | 41          |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 49          |
# |    gen/time/total_timesteps        | 8192        |
# |    gen/train/approx_kl             | 0.013806209 |
# |    gen/train/clip_fraction         | 0.241       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -2.81       |
# |    gen/train/explained_variance    | 0.123       |
# |    gen/train/learning_rate         | 0.0003      |
# |    gen/train/loss                  | 100         |
# |    gen/train/n_updates             | 30          |
# |    gen/train/policy_gradient_loss  | 0.0235      |
# |    gen/train/std                   | 0.986       |
# |    gen/train/value_loss            | 289         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.703    |
# |    disc/disc_acc_expert             | 0.75     |
# |    disc/disc_acc_gen                | 0.656    |
# |    disc/disc_entropy                | 0.17     |
# |    disc/disc_loss                   | 2.13     |
# |    disc/disc_proportion_expert_pred | 0.547    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.656    |
# |    disc/disc_acc_expert             | 0.875    |
# |    disc/disc_acc_gen                | 0.438    |
# |    disc/disc_entropy                | 0.193    |
# |    disc/disc_loss                   | 1.57     |
# |    disc/disc_proportion_expert_pred | 0.719    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.594    |
# |    disc/disc_acc_expert             | 0.609    |
# |    disc/disc_acc_gen                | 0.578    |
# |    disc/disc_entropy                | 0.289    |
# |    disc/disc_loss                   | 1.09     |
# |    disc/disc_proportion_expert_pred | 0.516    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.602    |
# |    disc/disc_acc_expert             | 0.672    |
# |    disc/disc_acc_gen                | 0.531    |
# |    disc/disc_entropy                | 0.229    |
# |    disc/disc_loss                   | 1.24     |
# |    disc/disc_proportion_expert_pred | 0.57     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.639    |
# |    disc/disc_acc_expert             | 0.727    |
# |    disc/disc_acc_gen                | 0.551    |
# |    disc/disc_entropy                | 0.22     |
# |    disc/disc_loss                   | 1.51     |
# |    disc/disc_proportion_expert_pred | 0.588    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 159      |
# |    gen/time/fps                     | 41       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 49       |
# |    gen/time/total_timesteps         | 8.19e+03 |
# |    gen/train/approx_kl              | 0.026    |
# |    gen/train/clip_fraction          | 0.309    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -2.81    |
# |    gen/train/explained_variance     | 0.674    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 843      |
# |    gen/train/n_updates              | 40       |
# |    gen/train/policy_gradient_loss   | 0.042    |
# |    gen/train/std                    | 0.986    |
# |    gen/train/value_loss             | 1.55e+03 |
# --------------------------------------------------
# round:   3%|▉                                 | 4/146 [04:05<2:23:25, 60.61s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_rew_wrapped_mean | 294        |
# |    gen/time/fps                    | 49         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 41         |
# |    gen/time/total_timesteps        | 10240      |
# |    gen/train/approx_kl             | 0.02602458 |
# |    gen/train/clip_fraction         | 0.309      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -2.81      |
# |    gen/train/explained_variance    | 0.674      |
# |    gen/train/learning_rate         | 0.0003     |
# |    gen/train/loss                  | 843        |
# |    gen/train/n_updates             | 40         |
# |    gen/train/policy_gradient_loss  | 0.042      |
# |    gen/train/std                   | 0.986      |
# |    gen/train/value_loss            | 1.55e+03   |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.672    |
# |    disc/disc_acc_expert             | 0.609    |
# |    disc/disc_acc_gen                | 0.734    |
# |    disc/disc_entropy                | 0.151    |
# |    disc/disc_loss                   | 1.47     |
# |    disc/disc_proportion_expert_pred | 0.438    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.641    |
# |    disc/disc_acc_expert             | 0.547    |
# |    disc/disc_acc_gen                | 0.734    |
# |    disc/disc_entropy                | 0.188    |
# |    disc/disc_loss                   | 1.56     |
# |    disc/disc_proportion_expert_pred | 0.406    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.719    |
# |    disc/disc_acc_expert             | 0.594    |
# |    disc/disc_acc_gen                | 0.844    |
# |    disc/disc_entropy                | 0.206    |
# |    disc/disc_loss                   | 0.888    |
# |    disc/disc_proportion_expert_pred | 0.375    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.688    |
# |    disc/disc_acc_expert             | 0.688    |
# |    disc/disc_acc_gen                | 0.688    |
# |    disc/disc_entropy                | 0.235    |
# |    disc/disc_loss                   | 1.03     |
# |    disc/disc_proportion_expert_pred | 0.5      |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.68     |
# |    disc/disc_acc_expert             | 0.609    |
# |    disc/disc_acc_gen                | 0.75     |
# |    disc/disc_entropy                | 0.195    |
# |    disc/disc_loss                   | 1.24     |
# |    disc/disc_proportion_expert_pred | 0.43     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 294      |
# |    gen/time/fps                     | 49       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 41       |
# |    gen/time/total_timesteps         | 1.02e+04 |
# |    gen/train/approx_kl              | 0.042    |
# |    gen/train/clip_fraction          | 0.304    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -2.81    |
# |    gen/train/explained_variance     | 0.594    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 365      |
# |    gen/train/n_updates              | 50       |
# |    gen/train/policy_gradient_loss   | 0.0149   |
# |    gen/train/std                    | 0.986    |
# |    gen/train/value_loss             | 1.52e+03 |
# --------------------------------------------------
# round:   3%|█▏                                | 5/146 [04:57<2:15:30, 57.67s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_rew_wrapped_mean | 253        |
# |    gen/time/fps                    | 49         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 41         |
# |    gen/time/total_timesteps        | 12288      |
# |    gen/train/approx_kl             | 0.04202067 |
# |    gen/train/clip_fraction         | 0.304      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -2.81      |
# |    gen/train/explained_variance    | 0.594      |
# |    gen/train/learning_rate         | 0.0003     |
# |    gen/train/loss                  | 365        |
# |    gen/train/n_updates             | 50         |
# |    gen/train/policy_gradient_loss  | 0.0149     |
# |    gen/train/std                   | 0.986      |
# |    gen/train/value_loss            | 1.52e+03   |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.812    |
# |    disc/disc_acc_expert             | 0.828    |
# |    disc/disc_acc_gen                | 0.797    |
# |    disc/disc_entropy                | 0.264    |
# |    disc/disc_loss                   | 0.696    |
# |    disc/disc_proportion_expert_pred | 0.516    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.828    |
# |    disc/disc_acc_expert             | 0.969    |
# |    disc/disc_acc_gen                | 0.688    |
# |    disc/disc_entropy                | 0.19     |
# |    disc/disc_loss                   | 0.492    |
# |    disc/disc_proportion_expert_pred | 0.641    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.836    |
# |    disc/disc_acc_expert             | 0.875    |
# |    disc/disc_acc_gen                | 0.797    |
# |    disc/disc_entropy                | 0.159    |
# |    disc/disc_loss                   | 0.588    |
# |    disc/disc_proportion_expert_pred | 0.539    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.797    |
# |    disc/disc_acc_expert             | 0.688    |
# |    disc/disc_acc_gen                | 0.906    |
# |    disc/disc_entropy                | 0.19     |
# |    disc/disc_loss                   | 0.616    |
# |    disc/disc_proportion_expert_pred | 0.391    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.818    |
# |    disc/disc_acc_expert             | 0.84     |
# |    disc/disc_acc_gen                | 0.797    |
# |    disc/disc_entropy                | 0.201    |
# |    disc/disc_loss                   | 0.598    |
# |    disc/disc_proportion_expert_pred | 0.521    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 253      |
# |    gen/time/fps                     | 49       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 41       |
# |    gen/time/total_timesteps         | 1.23e+04 |
# |    gen/train/approx_kl              | 0.166    |
# |    gen/train/clip_fraction          | 0.384    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -2.81    |
# |    gen/train/explained_variance     | 0.565    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 342      |
# |    gen/train/n_updates              | 60       |
# |    gen/train/policy_gradient_loss   | 0.039    |
# |    gen/train/std                    | 0.987    |
# |    gen/train/value_loss             | 888      |
# --------------------------------------------------
# round:   4%|█▍                                | 6/146 [05:50<2:10:28, 55.92s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_rew_wrapped_mean | 231        |
# |    gen/time/fps                    | 51         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 39         |
# |    gen/time/total_timesteps        | 14336      |
# |    gen/train/approx_kl             | 0.16559553 |
# |    gen/train/clip_fraction         | 0.384      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -2.81      |
# |    gen/train/explained_variance    | 0.565      |
# |    gen/train/learning_rate         | 0.0003     |
# |    gen/train/loss                  | 342        |
# |    gen/train/n_updates             | 60         |
# |    gen/train/policy_gradient_loss  | 0.039      |
# |    gen/train/std                   | 0.987      |
# |    gen/train/value_loss            | 888        |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.586    |
# |    disc/disc_acc_expert             | 0.75     |
# |    disc/disc_acc_gen                | 0.422    |
# |    disc/disc_entropy                | 0.243    |
# |    disc/disc_loss                   | 1.08     |
# |    disc/disc_proportion_expert_pred | 0.664    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.797    |
# |    disc/disc_acc_expert             | 0.672    |
# |    disc/disc_acc_gen                | 0.922    |
# |    disc/disc_entropy                | 0.148    |
# |    disc/disc_loss                   | 0.639    |
# |    disc/disc_proportion_expert_pred | 0.375    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.812    |
# |    disc/disc_acc_expert             | 0.75     |
# |    disc/disc_acc_gen                | 0.875    |
# |    disc/disc_entropy                | 0.105    |
# |    disc/disc_loss                   | 0.856    |
# |    disc/disc_proportion_expert_pred | 0.438    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.82     |
# |    disc/disc_acc_expert             | 0.766    |
# |    disc/disc_acc_gen                | 0.875    |
# |    disc/disc_entropy                | 0.166    |
# |    disc/disc_loss                   | 0.72     |
# |    disc/disc_proportion_expert_pred | 0.445    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.754    |
# |    disc/disc_acc_expert             | 0.734    |
# |    disc/disc_acc_gen                | 0.773    |
# |    disc/disc_entropy                | 0.165    |
# |    disc/disc_loss                   | 0.825    |
# |    disc/disc_proportion_expert_pred | 0.48     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 7        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 231      |
# |    gen/time/fps                     | 51       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 39       |
# |    gen/time/total_timesteps         | 1.43e+04 |
# |    gen/train/approx_kl              | 0.0927   |
# |    gen/train/clip_fraction          | 0.459    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -2.81    |
# |    gen/train/explained_variance     | 0.49     |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 1.16e+03 |
# |    gen/train/n_updates              | 70       |
# |    gen/train/policy_gradient_loss   | 0.0562   |
# |    gen/train/std                    | 0.987    |
# |    gen/train/value_loss             | 2.03e+03 |
# --------------------------------------------------
# round:   5%|█▋                                | 7/146 [06:41<2:05:56, 54.36s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_rew_wrapped_mean | 252        |
# |    gen/time/fps                    | 61         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 33         |
# |    gen/time/total_timesteps        | 16384      |
# |    gen/train/approx_kl             | 0.09267752 |
# |    gen/train/clip_fraction         | 0.459      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -2.81      |
# |    gen/train/explained_variance    | 0.49       |
# |    gen/train/learning_rate         | 0.0003     |
# |    gen/train/loss                  | 1.16e+03   |
# |    gen/train/n_updates             | 70         |
# |    gen/train/policy_gradient_loss  | 0.0562     |
# |    gen/train/std                   | 0.987      |
# |    gen/train/value_loss            | 2.03e+03   |
# ---------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.672    |
# |    disc/disc_acc_expert             | 0.688    |
# |    disc/disc_acc_gen                | 0.656    |
# |    disc/disc_entropy                | 0.201    |
# |    disc/disc_loss                   | 1.21     |
# |    disc/disc_proportion_expert_pred | 0.516    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 8        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.828    |
# |    disc/disc_acc_expert             | 0.844    |
# |    disc/disc_acc_gen                | 0.812    |
# |    disc/disc_entropy                | 0.142    |
# |    disc/disc_loss                   | 0.48     |
# |    disc/disc_proportion_expert_pred | 0.516    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 8        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.797    |
# |    disc/disc_acc_expert             | 0.75     |
# |    disc/disc_acc_gen                | 0.844    |
# |    disc/disc_entropy                | 0.167    |
# |    disc/disc_loss                   | 0.623    |
# |    disc/disc_proportion_expert_pred | 0.453    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 8        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.758    |
# |    disc/disc_acc_expert             | 0.828    |
# |    disc/disc_acc_gen                | 0.688    |
# |    disc/disc_entropy                | 0.221    |
# |    disc/disc_loss                   | 0.623    |
# |    disc/disc_proportion_expert_pred | 0.57     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 8        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.764    |
# |    disc/disc_acc_expert             | 0.777    |
# |    disc/disc_acc_gen                | 0.75     |
# |    disc/disc_entropy                | 0.183    |
# |    disc/disc_loss                   | 0.734    |
# |    disc/disc_proportion_expert_pred | 0.514    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 8        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 252      |
# |    gen/time/fps                     | 61       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 33       |
# |    gen/time/total_timesteps         | 1.64e+04 |
# |    gen/train/approx_kl              | 3.15     |
# |    gen/train/clip_fraction          | 0.839    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -2.81    |
# |    gen/train/explained_variance     | 0.485    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 398      |
# |    gen/train/n_updates              | 80       |
# |    gen/train/policy_gradient_loss   | 0.165    |
# |    gen/train/std                    | 0.987    |
# |    gen/train/value_loss             | 1.45e+03 |
# --------------------------------------------------
# round:   5%|█▊                                | 8/146 [07:26<1:57:53, 51.26s/it]
# --------------------------------------------------
# | raw/                               |           |
# |    gen/rollout/ep_rew_wrapped_mean | 247       |
# |    gen/time/fps                    | 82        |
# |    gen/time/iterations             | 1         |
# |    gen/time/time_elapsed           | 24        |
# |    gen/time/total_timesteps        | 18432     |
# |    gen/train/approx_kl             | 3.1465323 |
# |    gen/train/clip_fraction         | 0.839     |
# |    gen/train/clip_range            | 0.2       |
# |    gen/train/entropy_loss          | -2.81     |
# |    gen/train/explained_variance    | 0.485     |
# |    gen/train/learning_rate         | 0.0003    |
# |    gen/train/loss                  | 398       |
# |    gen/train/n_updates             | 80        |
# |    gen/train/policy_gradient_loss  | 0.165     |
# |    gen/train/std                   | 0.987     |
# |    gen/train/value_loss            | 1.45e+03  |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.562    |
# |    disc/disc_acc_expert             | 0.859    |
# |    disc/disc_acc_gen                | 0.266    |
# |    disc/disc_entropy                | 0.246    |
# |    disc/disc_loss                   | 1.27     |
# |    disc/disc_proportion_expert_pred | 0.797    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.781    |
# |    disc/disc_acc_expert             | 0.828    |
# |    disc/disc_acc_gen                | 0.734    |
# |    disc/disc_entropy                | 0.191    |
# |    disc/disc_loss                   | 0.53     |
# |    disc/disc_proportion_expert_pred | 0.547    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.875    |
# |    disc/disc_acc_expert             | 0.812    |
# |    disc/disc_acc_gen                | 0.938    |
# |    disc/disc_entropy                | 0.082    |
# |    disc/disc_loss                   | 0.619    |
# |    disc/disc_proportion_expert_pred | 0.438    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.852    |
# |    disc/disc_acc_expert             | 0.734    |
# |    disc/disc_acc_gen                | 0.969    |
# |    disc/disc_entropy                | 0.112    |
# |    disc/disc_loss                   | 0.517    |
# |    disc/disc_proportion_expert_pred | 0.383    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.768    |
# |    disc/disc_acc_expert             | 0.809    |
# |    disc/disc_acc_gen                | 0.727    |
# |    disc/disc_entropy                | 0.158    |
# |    disc/disc_loss                   | 0.735    |
# |    disc/disc_proportion_expert_pred | 0.541    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 9        |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 247      |
# |    gen/time/fps                     | 82       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 24       |
# |    gen/time/total_timesteps         | 1.84e+04 |
# |    gen/train/approx_kl              | 85       |
# |    gen/train/clip_fraction          | 0.903    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -2.81    |
# |    gen/train/explained_variance     | 0.319    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 179      |
# |    gen/train/n_updates              | 90       |
# |    gen/train/policy_gradient_loss   | 0.239    |
# |    gen/train/std                    | 0.987    |
# |    gen/train/value_loss             | 647      |
# --------------------------------------------------
# round:   6%|██                                | 9/146 [08:02<1:46:13, 46.52s/it]
# -------------------------------------------------
# | raw/                               |          |
# |    gen/rollout/ep_rew_wrapped_mean | 276      |
# |    gen/time/fps                    | 95       |
# |    gen/time/iterations             | 1        |
# |    gen/time/time_elapsed           | 21       |
# |    gen/time/total_timesteps        | 20480    |
# |    gen/train/approx_kl             | 85.03761 |
# |    gen/train/clip_fraction         | 0.903    |
# |    gen/train/clip_range            | 0.2      |
# |    gen/train/entropy_loss          | -2.81    |
# |    gen/train/explained_variance    | 0.319    |
# |    gen/train/learning_rate         | 0.0003   |
# |    gen/train/loss                  | 179      |
# |    gen/train/n_updates             | 90       |
# |    gen/train/policy_gradient_loss  | 0.239    |
# |    gen/train/std                   | 0.987    |
# |    gen/train/value_loss            | 647      |
# -------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.859    |
# |    disc/disc_acc_expert             | 0.766    |
# |    disc/disc_acc_gen                | 0.953    |
# |    disc/disc_entropy                | 0.121    |
# |    disc/disc_loss                   | 0.773    |
# |    disc/disc_proportion_expert_pred | 0.406    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 10       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.914    |
# ...
# |    gen/train/policy_gradient_loss  | 0.0777    |
# |    gen/train/std                   | 1.69      |
# |    gen/train/value_loss            | 19        |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.867    |
# |    disc/disc_acc_expert             | 0.797    |
# |    disc/disc_acc_gen                | 0.938    |
# |    disc/disc_entropy                | 0.32     |
# |    disc/disc_loss                   | 0.3      |
# |    disc/disc_proportion_expert_pred | 0.43     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 75       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.883    |
# |    disc/disc_acc_expert             | 0.891    |
# |    disc/disc_acc_gen                | 0.875    |
# |    disc/disc_entropy                | 0.308    |
# |    disc/disc_loss                   | 0.339    |
# |    disc/disc_proportion_expert_pred | 0.508    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 75       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.859    |
# |    disc/disc_acc_expert             | 0.844    |
# |    disc/disc_acc_gen                | 0.875    |
# |    disc/disc_entropy                | 0.281    |
# |    disc/disc_loss                   | 0.345    |
# |    disc/disc_proportion_expert_pred | 0.484    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 75       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.883    |
# |    disc/disc_acc_expert             | 0.844    |
# |    disc/disc_acc_gen                | 0.922    |
# |    disc/disc_entropy                | 0.246    |
# |    disc/disc_loss                   | 0.336    |
# |    disc/disc_proportion_expert_pred | 0.461    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 75       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.873    |
# |    disc/disc_acc_expert             | 0.844    |
# |    disc/disc_acc_gen                | 0.902    |
# |    disc/disc_entropy                | 0.289    |
# |    disc/disc_loss                   | 0.33     |
# |    disc/disc_proportion_expert_pred | 0.471    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 75       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 97.7     |
# |    gen/time/fps                     | 97       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 20       |
# |    gen/time/total_timesteps         | 1.54e+05 |
# |    gen/train/approx_kl              | 0.723    |
# |    gen/train/clip_fraction          | 0.718    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -3.9     |
# |    gen/train/explained_variance     | 0.278    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 0.604    |
# |    gen/train/n_updates              | 750      |
# |    gen/train/policy_gradient_loss   | 0.101    |
# |    gen/train/std                    | 1.71     |
# |    gen/train/value_loss             | 9.76     |
# --------------------------------------------------
# round:  51%|█████████████████▉                 | 75/146 [45:04<38:51, 32.83s/it]
# --------------------------------------------------
# | raw/                               |           |
# |    gen/rollout/ep_rew_wrapped_mean | 92.4      |
# |    gen/time/fps                    | 96        |
# |    gen/time/iterations             | 1         |
# |    gen/time/time_elapsed           | 21        |
# |    gen/time/total_timesteps        | 155648    |
# |    gen/train/approx_kl             | 0.7234811 |
# |    gen/train/clip_fraction         | 0.718     |
# |    gen/train/clip_range            | 0.2       |
# |    gen/train/entropy_loss          | -3.9      |
# |    gen/train/explained_variance    | 0.278     |
# |    gen/train/learning_rate         | 0.0003    |
# |    gen/train/loss                  | 0.604     |
# |    gen/train/n_updates             | 750       |
# |    gen/train/policy_gradient_loss  | 0.101     |
# |    gen/train/std                   | 1.71      |
# |    gen/train/value_loss            | 9.76      |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.906    |
# |    disc/disc_acc_expert             | 0.859    |
# |    disc/disc_acc_gen                | 0.953    |
# |    disc/disc_entropy                | 0.212    |
# |    disc/disc_loss                   | 0.224    |
# |    disc/disc_proportion_expert_pred | 0.453    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 76       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.93     |
# |    disc/disc_acc_expert             | 0.891    |
# |    disc/disc_acc_gen                | 0.969    |
# |    disc/disc_entropy                | 0.173    |
# |    disc/disc_loss                   | 0.177    |
# |    disc/disc_proportion_expert_pred | 0.461    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 76       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.883    |
# |    disc/disc_acc_expert             | 0.844    |
# |    disc/disc_acc_gen                | 0.922    |
# |    disc/disc_entropy                | 0.156    |
# |    disc/disc_loss                   | 0.215    |
# |    disc/disc_proportion_expert_pred | 0.461    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 76       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.922    |
# |    disc/disc_acc_expert             | 0.875    |
# |    disc/disc_acc_gen                | 0.969    |
# |    disc/disc_entropy                | 0.126    |
# |    disc/disc_loss                   | 0.161    |
# |    disc/disc_proportion_expert_pred | 0.453    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 76       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.91     |
# |    disc/disc_acc_expert             | 0.867    |
# |    disc/disc_acc_gen                | 0.953    |
# |    disc/disc_entropy                | 0.167    |
# |    disc/disc_loss                   | 0.194    |
# |    disc/disc_proportion_expert_pred | 0.457    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 76       |
# |    disc/n_expert                    | 64       |
# |    disc/n_generated                 | 64       |
# |    gen/rollout/ep_rew_wrapped_mean  | 92.4     |
# |    gen/time/fps                     | 96       |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 21       |
# |    gen/time/total_timesteps         | 1.56e+05 |
# |    gen/train/approx_kl              | 0.816    |
# |    gen/train/clip_fraction          | 0.779    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -3.93    |
# |    gen/train/explained_variance     | 0.492    |
# |    gen/train/learning_rate          | 0.0003   |
# |    gen/train/loss                   | 0.689    |
# |    gen/train/n_updates              | 760      |
# |    gen/train/policy_gradient_loss   | 0.0948   |
# |    gen/train/std                    | 1.74     |
# |    gen/train/value_loss             | 12.6     |
# --------------------------------------------------
# round:  52%|██████████████████▏                | 76/146 [45:37<38:12, 32.75s/it]
# ---------------------------------------------------
# | raw/                               |            |
# |    gen/rollout/ep_rew_wrapped_mean | 85.9       |
# |    gen/time/fps                    | 95         |
# |    gen/time/iterations             | 1          |
# |    gen/time/time_elapsed           | 21         |
# |    gen/time/total_timesteps        | 157696     |
# |    gen/train/approx_kl             | 0.81636596 |
# |    gen/train/clip_fraction         | 0.779      |
# |    gen/train/clip_range            | 0.2        |
# |    gen/train/entropy_loss          | -3.93      |
# |    gen/train/explained_variance    | 0.492      |
# |    gen/train/learning_rate         | 0.0003     |
# |    gen/train/loss                  | 0.689      |
# |    gen/train/n_updates             | 760        |
# |    gen/train/policy_gradient_loss  | 0.0948     |
# |    gen/train/std                   | 1.74       |
# |    gen/train/value_loss            | 12.6       |
# ---------------------------------------------------
# Process ForkServerProcess-1:
# Traceback (most recent call last):
#   File "/home/koksyuen/anaconda3/envs/rl/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/koksyuen/anaconda3/envs/rl/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/koksyuen/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 28, in _worker
#     cmd, data = remote.recv()
#   File "/home/koksyuen/anaconda3/envs/rl/lib/python3.8/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/koksyuen/anaconda3/envs/rl/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/koksyuen/anaconda3/envs/rl/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# round:  52%|██████████████████▏                | 76/146 [46:02<42:23, 36.34s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 gail_trainer.train(300000)
#
# File ~/anaconda3/envs/rl/lib/python3.8/site-packages/imitation/algorithms/adversarial/common.py:448, in AdversarialTrainer.train(self, total_timesteps, callback)
#     442 assert n_rounds >= 1, (
#     443     "No updates (need at least "
#     444     f"{self.gen_train_timesteps} timesteps, have only "
#     445     f"total_timesteps={total_timesteps})!"
#     446 )
#     447 for r in tqdm.tqdm(range(0, n_rounds), desc="round"):
# --> 448     self.train_gen(self.gen_train_timesteps)
#     449     for _ in range(self.n_disc_updates_per_round):
#     450         with networks.training(self.reward_train):
#     451             # switch to training mode (affects dropout, normalization)
#
# File ~/anaconda3/envs/rl/lib/python3.8/site-packages/imitation/algorithms/adversarial/common.py:408, in AdversarialTrainer.train_gen(self, total_timesteps, learn_kwargs)
#     405     learn_kwargs = {}
#     407 with self.logger.accumulate_means("gen"):
# --> 408     self.gen_algo.learn(
#     409         total_timesteps=total_timesteps,
#     410         reset_num_timesteps=False,
#     411         callback=self.gen_callback,
#     412         **learn_kwargs,
#     413     )
#     414     self._global_step += 1
#     416 gen_trajs, ep_lens = self.venv_buffering.pop_trajectories()
#
# File ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:271, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     268         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     269         self.logger.dump(step=self.num_timesteps)
# --> 271     self.train()
#     273 callback.on_training_end()
#     275 return self
#
# File ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py:200, in PPO.train(self)
#     198 approx_kl_divs = []
#     199 # Do a complete pass on the rollout buffer
# --> 200 for rollout_data in self.rollout_buffer.get(self.batch_size):
#     201     actions = rollout_data.actions
#     202     if isinstance(self.action_space, spaces.Discrete):
#     203         # Convert discrete action from float to long
#
# File ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/buffers.py:470, in RolloutBuffer.get(self, batch_size)
#     468 start_idx = 0
#     469 while start_idx < self.buffer_size * self.n_envs:
# --> 470     yield self._get_samples(indices[start_idx : start_idx + batch_size])
#     471     start_idx += batch_size
#
# File ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/buffers.py:486, in RolloutBuffer._get_samples(self, batch_inds, env)
#     473 def _get_samples(
#     474     self,
#     475     batch_inds: np.ndarray,
#     476     env: Optional[VecNormalize] = None,
#     477 ) -> RolloutBufferSamples:  # type: ignore[signature-mismatch] #FIXME
#     478     data = (
#     479         self.observations[batch_inds],
#     480         self.actions[batch_inds],
#    (...)
#     484         self.returns[batch_inds].flatten(),
#     485     )
# --> 486     return RolloutBufferSamples(*tuple(map(self.to_torch, data)))
#
# File ~/anaconda3/envs/rl/lib/python3.8/site-packages/stable_baselines3/common/buffers.py:135, in BaseBuffer.to_torch(self, array, copy)
#     125 """
#     126 Convert a numpy array to a PyTorch tensor.
#     127 Note: it copies the data by default
#    (...)
#     132 :return:
#     133 """
#     134 if copy:
# --> 135     return th.tensor(array, device=self.device)
#     136 return th.as_tensor(array, device=self.device)
#
# KeyboardInterrupt:

# %%
learner.save('./train/GAIL/model1')
